# %% [markdown]
# # 1.1 Programming (general)

# %% [markdown]
# ## participation activity 1.1.1: A basic computer program.
# ### Computer program basics
#
# Computer programs are abundant in many people's lives today, carrying out applications on smartphones, tablets, and laptops, powering businesses like Amazon and Netflix, helping cars drive and planes fly, and much more.
#
# A computer program consists of instructions executing one at a time. Basic instruction types are:
#
# -   Input: A program receives data from a file, keyboard, touchscreen, network, etc.
# -   Process: A program performs computations on that data, such as adding two values like x + y.
# -   Output: A program puts that data somewhere, such as a file, screen, or network.
#
# Programs use variables to refer to data, like x, y, and z below. The name is due to a variable's value "varying" as a program assigns a variable like x with new value

# %%
#First, let's get the inputs. In Python, you can use the `input()` function to get user input.
#1. Get the first input and convert it to an integer
x = int(input("Enter the first number (x): "))

#2. Get the second input and convert it to an integer
y = int(input("Enter the second number (y): "))

#3. Process: add x and y
##*Next*, the program processes the input by adding `x` and `y` and assigning the result to `z`.
z = x + y
# Finally, the program puts `z` to output, displaying it on the screen.
#4. Output: display the value of z
print(f"The sum (z) is: {z}")
# Out:
# Enter the first number (x): 2
# Enter the second number (y): 5
# The sum (z) is: 7

# %%
x=int(input("Input int x:"))
y=int(input("Input int y:"))
z=x+y
print(f"The sum (z) is: {z}")
print("\n")
print("The sum z is equal to",z)
print(end="\n")
print(f"The sum of {x} and {y} is {z}")
print(f'''
{z} is the sum of {x} and {y}
''')
end="\n"
print(end)


print(f"The sum (z) is: {z}")
# Out:
# Input int x:2
# Input int y:5
# The sum (z) is: 7
#
#
# The sum z is equal to 7
#
# The sum of 2 and 5 is 7
#
# 7 is the sum of 2 and 5
#
#
#
# The sum (z) is: 7

# %% [markdown]
# ## participation activity 1.1.2: A basic computer program.

# %% [markdown]
# ### 1) How many instructions does the program have?
#
# > Add blockquote
#
#
# given:
# ```
# x=int(input("Input int x:"))
# y=int(input("Input int y:"))
# z=x+y
# print("The sum z is equal to",z)
# ```

# %%
print('''
4
The program has two input instructions, one processing instruction, and one output instruction, totaling four instructions.
''')
# Out:
# 4
# The program has two input instructions, one processing instruction, and one output instruction, totaling four instructions.

# %% [markdown]
# ### 2.Suppose a new instruction were inserted as follows:
# ```
# ...
# z = x + y
# Add 1 to z (new instruction)
# Put z to output
#
# What would the last instruction output to the screen?
# ```

# %%
import time
x=int(input("Input int x:"))
y=int(input("Input int y:"))
z=x+y
time.sleep(0.5)
print("doing z=z+1 now")
time.sleep(0.5)
z=z+1
time.sleep(0.5)
print(f"final z is {z}")


'''
x=int(input("Input int x:"))
y=int(input("Input int y:"))
z=x+y
z=z+1
'''
# Out:
# Input int x:2
# Input int y:5
# doing z=z+1 now
# final z is 8
# '\nx=int(input("Input int x:"))\ny=int(input("Input int y:"))\nz=x+y\nz=z+1\n'

# %% [markdown]
# ### 3)Consider the instruction:
# ```z = x + y.```
#
# **If x is 10 and y is 20, then z is assigned with _____.**
#
# *Note that in programming, the instruction z = x + y has a different meaning than in traditional algebra. In algebra, z = x + y states an equality: z is the same as x + y. But in programming, z = x + y is an assignment: z is assigned with the sum of the current values of x and y.*

# %%
#This code will output `True` because `z` does indeed become `30` after the calculation. The `==` operator is used to ask a question: 'Is this value equal to that value?'
x = 10
y = 20
z = x + y

# Check if z is equal to 30
is_z_thirty = (z == 30)

print(f"The value of z is: {z}")
print(f"Is z equal to 30? {is_z_thirty}")
# Out:
# The value of z is: 30
# Is z equal to 30? True

# %%
x=10
y=20
z=x+y
equality=(z==30)
if equality==True:
  print(f"The value of z is: {z}")
elif equality==False:
  print(f"the value of z is not equal to 30")
else:
  print("Something unexpected happened with the equality check.")
# Out:
# The value of z is: 30

# %%
x=10
y=20
z=x+y
equality=(z==30)
if equality:
  print(f"The value of z is: {z}")
# Out:
# The value of z is: 30

# %%
x=10
y=20
z=x+y
equality=(z==30)
print(f"Is z equal to 30? {equality}")
# Out:
# Is z equal to 30? True

# %% [markdown]
# ## 1.1.3: A first programming activity.
# ### A program is like a recipe
#
# Some people think of a program as being like a cooking recipe. A recipe consists of _instructions_ that a chef executes, like adding eggs or stirring ingredients.
#
# #### **Baking chocolate chip cookies from a recipe**
#
# 1.  Mix one stick of butter and one cup of sugar.
# 2.  Add egg and mix until combined.
# 3.  Stir in flour and chocolate.
# 4.  Bake at 350°F for 8 minutes.
#
# Likewise, a computer program consists of instructions that a computer executes, like multiplying numbers or outputting a number to a screen.
#
# ---
# Below is a simple tool that allows a user to rearrange pre-written instructions (in no particular programming language). The tool illustrates how a computer executes each instruction one at a time, assigning variable m with new values throughout, and outputting ("printing") values to the screen.

# %%
#Here's a possible sequence of instructions and the state of `m` after each step:

# Initial instruction
m = 5
print(f"After m = 5, m is: {m}")

# Rearranged instructions to maximize m
m = m * m  # m becomes 5 * 5 = 25
print(f"After m = m * m, m is: {m}")

m = m * 2  # m becomes 25 * 2 = 50
print(f"After m = m * 2, m is: {m}")

m = m * m  # m becomes 50 * 50 = 2500
print(f"After m = m * m again, m is: {m}")

m = m + 15 # m becomes 2500 + 15 = 2515
print(f"After m = m + 15, m is: {m}")

# The final 'put m' instruction would output this value:
print(f"Final output: {m}")

# As you can see, by rearranging the instructions, especially by doing the `m = m * m` step after `m` has already grown, we can easily achieve a value much greater than 1,000! In this sequence, the final output would be **2515**.
# Out:
# After m = 5, m is: 5
# After m = m * m, m is: 25
# After m = m * 2, m is: 50
# After m = m * m again, m is: 2500
# After m = m + 15, m is: 2515
# Final output: 2515

# %%
import random


def multiply(int1,int2):
  int1 = int(int1)
  int2 = int(int2)
  print(f"{int1} * {int2} = {int1*int2}")
  return int1*int2
def add(int1,int2):
  int1 = int(int1)
  int2 = int(int2)
  print(f"{int1} + {int2} = {int1+int2}")
  return int1+int2
def square(int1):
  int1 = int(int1)
  print(f"{int1} * {int1} = {int1**2}")
  return int1**2

#m = random.randint(1, 10)
m=5
print(f"m = {m}")
'''
multiply(m,2)
add(m,15)
square(m)
'''

m=multiply(m,2)
m=square(m)
m=add(m,15)
print(f"Final output: {m}\n")

y=5
y=multiply(square(add(y,15)),2)
print("\n")
x=5
x=add(square(multiply(x,2)),15)

#sorry i shoudlnt get into bad habits
z=5
z= z*2
z=z*z
z=z+15
print(f"\n{z}")
# Out:
# m = 5
# 5 * 2 = 10
# 10 * 10 = 100
# 100 + 15 = 115
# Final output: 115
#
# 5 + 15 = 20
# 20 * 20 = 400
# 400 * 2 = 800
#
#
# 5 * 2 = 10
# 10 * 10 = 100
# 100 + 15 = 115
#
# 115

# %% [markdown]
# ### Function Chaining Example
#
# Let's use your `multiply`, `add`, and `square` functions to demonstrate chaining. We'll start with `m = 5` and perform a series of operations:
#
# 1.  Multiply `m` by 2.
# 2.  Add 15 to the result.
# 3.  Square that new result.

# %%
# Start with m = 5
m_initial = 5
print(f"Initial m: {m_initial}")

# Chaining operations:
# m = multiply(m, 2)
# m = add(m, 15)
# m = square(m)

# We can combine these into a single line by passing the result of one function
# directly as an argument to the next function.

# Let's say we want to:
# 1. Multiply the initial m by 2
# 2. Add 15 to that result
# 3. Square the final result

# Step-by-step for clarity first:
result_mult = multiply(m_initial, 2)  # 5 * 2 = 10
result_add = add(result_mult, 15)     # 10 + 15 = 25
final_result = square(result_add)    # 25 * 25 = 625
print(f"\nStep-by-step final result: {final_result}")

# Now, let's chain them directly:
chained_result = square(add(multiply(m_initial, 2), 15))
print(f"Chained final result: {chained_result}")

# You can see that both approaches yield the same result, but chaining makes the code more compact.
# Out:
# Initial m: 5
# 5 * 2 = 10
# 10 + 15 = 25
# 25 * 25 = 625
#
# Step-by-step final result: 625
# 5 * 2 = 10
# 10 + 15 = 25
# 25 * 25 = 625
# Chained final result: 625

# %% [markdown]
# ## participation activity 1.1.4: Instructions.

# %% [markdown]
# ### 1) Which instruction completes the program to compute a triangle's area?
# ```
# Which instruction completes the program to compute a triangle's area?
# base = Get next input
# height = Get next input
# Assign x with base * height
# _____
# Put x to output
# ```

# %%
base=int(input("Input base:"))
height=int(input("Input height:"))

x=base*height
x=x*1/2

print(f"The area is: {x}")
# Out:
# Input base:2
# Input height:5
# The area is: 5.0

# %% [markdown]
#  **Multiply x by 1/2**
#
#  ``x=x*1/2``
#
#  A triangle's area is (1/2) * base * height.

# %% [markdown]
# ### 2) Which instruction completes the program to compute the average of three numbers?
# x = Get next input
# y = Get next input
# z = Get next input

# %%
import random
x=random.randint(1,10)
y=random.randint(1,10)
z=random.randint(1,10)

a=(x+y+z)/3

print(f"The average of {x},{y}, and {z} is:")
print(f"a = ({x}+{y}+{z})/3 = {a}")
# Out:
# The average of 3,8, and 2 is:
# a = (3+8+2)/3 = 4.333333333333333

# %% [markdown]
# ## 1.1.5: Computational thinking: Creating algorithms to draw shapes using turtle graphics.
#
# ### Computational thinking
#
# _Mathematical thinking_ became increasingly important throughout the industrial age, enabling people to successfully live and work. In the information age, many people believe computational thinking, or creating a sequence of instructions to solve a problem, will become increasingly important for work and everyday life. A sequence of instructions that solves a problem is called an algorithm.

# %% [markdown]
# # 1.2 Programming using Python
# ### Python interpreter
#
# The Python interpreter is a computer program that executes code written in the Python programming language. An interactive interpreter is a program that allows the user to execute one line of code at a time.
#
# Code is a common word for the textual representation of a program (and hence programming is also called _coding_). A line is a row of text.
#
# The interactive interpreter displays a prompt ("_\>>>_") that indicates the interpreter is ready to accept code. The user types a line of Python code and presses the enter key to execute the code. Initially, you may think of the interactive interpreter as a powerful calculator. The example program below calculates a salary based on a given hourly wage, the number of hours worked per week, and the number of weeks per year. The specifics of the code are described elsewhere in the chapter.
#
# -   After each press of the enter key, the python interpreter executes the line of code.
# -   The python interpreter can be used as a calculator to perform a variety of calculations.
# -   Users can change values and execute calculations again.

# %%
wage = 20
hours = 40
weeks = 52
salary = wage * hours * weeks
print(f"The salary is ${salary}")

hours = 35
salary = wage * hours * weeks
print(f"The salary is ${salary}")

print(f"{wage}, {hours}, {weeks} , {salary}")
# Out:
# The salary is $41600
# The salary is $36400
# 20, 35, 52 , 36400

# %% [markdown]
# ## 1.2.2: Match the Python terms with their definitions.

# %% [markdown]
# ```
# Interpreter:A program that executes computer code.
#
# Code:The text that represents a computer program.
#
# Prompt:Informs the programmer that the interpreter is ready to accept commands.
#
# Line:A row of text.
# ```

# %% [markdown]
# ## 1.2.3: Executing a simple Python program.
# ### Executing a Python program
#
# The Python interactive interpreter is useful for simple operations or programs consisting of only a few lines. However, entering code line-by-line into the interpreter quickly becomes unwieldy for any program spanning more than a few lines.
#
# Instead, a programmer can write Python code in a file then provide that file to the interpreter. The interpreter begins by executing the first line of code at the top of the file and continues until the interpreter reaches the end.
#
# -   A statement is a program instruction. A program mostly consists of a series of statements, and each statement usually appears on its own line.
# -   An expression is a piece of code the interpreter evaluates to produce a value; for example, the code `wage * hours * weeks` is an expression that computes a number. The symbol `*` is used for multiplication. The names wage, hours, weeks, and salary are variables, which are named references to values stored by the interpreter.
# -   A new variable is created by performing an assignment using the = symbol, such as `salary = wage * hours * weeks`, which creates a new variable called salary.
# -   The print() function displays variables or expression values.
# -   Characters such as "#" denote comments, which are optional but can be used to explain portions of code to a human reader.
# -   Many code editors color certain words, as in the below program, to assist a human reader in understanding various words' roles.

# %%
wage = 20
hours = 40
weeks = 52
salary = wage * hours * weeks

print("Salary is:", salary)

hours = 35
salary = wage * hours * weeks
print("New salary is:", salary)

'''The Python interpreter reads a file line by line. Variables wage, hours, and weeks are named references that refer to values stored by the interpreter.
20 * 40 * 52 is computed, and the variable salary is assigned with the value.
The print statement prints "Salary is:" to the screen and displays the value of the variable salary.
Values can be overwritten if the same variable name is used.'''
# Out:
# Salary is: 41600
# New salary is: 36400
# 'The Python interpreter reads a file line by line. Variables wage, hours, and weeks are named references that refer to values stored by the interpreter.\n20 * 40 * 52 is computed, and the variable salary is assigned with the value.\nThe print statement prints "Salary is:" to the screen and displays the value of the variable salary.\nValues can be overwritten if the same variable name is used.'

# %% [markdown]
# ### 1.2.4: Python basics.

# %% [markdown]
# 1)
# What is the purpose of variables?
# Correct
# Variables are used to refer to values saved in memory by the interpreter.
# 2)
# The code 20 * 40 is an expression.
# Correct
# Expressions are code that yield a value when evaluated, such as 20 * 40, which yields the value 800.
# 3)
# How are most Python programs developed?
# Correct
# The Python interpreter can load and execute Python code saved in files.
# 4)
# Comments are required in a program.
# Correct
# Comments are ignored by the interpreter, however comments are a helpful way to explain code to a reader of the program.
