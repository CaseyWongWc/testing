# %% [markdown]
# # ``# ▶``

# %% [markdown]
# # ♈

# %%
## @https://docs.google.com/document/d/1_UMO1vZrxXXtPEsHEOgqPaY63svjvCpepZxOtoWSSss/edit?tab=t.0
from google.colab import _message

notebook_json = _message.blocking_request('get_ipynb', request='', timeout_sec=10)
cells = notebook_json.get('ipynb', {}).get('cells', [])
extracted_cells_info = []

current_cell_id = 'pT_a8Zm8NbBM'
start_export_index = -1

# Find the index of the current cell within the notebook's cells
for idx, cell_obj in enumerate(cells):
    # Access the cell_id from metadata, as it's not always a top-level key
    if 'metadata' in cell_obj and 'id' in cell_obj['metadata'] and cell_obj['metadata']['id'] == current_cell_id:
        start_export_index = idx
        break

if start_export_index == -1:
    print(f"Error: Current cell '{current_cell_id}' not found in notebook. Please ensure the cell ID is correct or the notebook structure is as expected.")
else:
    # Iterate over cells starting *after* the current cell
    for i, cell in enumerate(cells[start_export_index + 1:]):
        cell_info = {
            'cell_number': start_export_index + 2 + i, # Original 1-based index for display
            'cell_type': cell.get('cell_type') or cell.get('cellType', 'unknown'),
            'source': ''.join(cell.get('source', [])) if isinstance(cell.get('source'), list) else cell.get('source', ''),
            'outputs': cell.get('outputs', []) if (cell.get('cell_type') or cell.get('cellType')) == 'code' else []
        }
        extracted_cells_info.append(cell_info)

formatted_content = ""

for cell_info in extracted_cells_info:
    cell_type = cell_info['cell_type']
    cell_number = cell_info['cell_number']
    source = cell_info['source']
    outputs = cell_info['outputs']

    formatted_content += f"{cell_type.capitalize()} Cell {cell_number}:\n"

    if cell_type == 'markdown':
        formatted_content += f"{source}\n\n"
    elif cell_type == 'code':
        formatted_content += f"```python\n{source}\n```\n"
        if outputs:
            formatted_content += "Output:\n"
            formatted_content += f"```\n{outputs}\n```\n\n"

print(f"Exporting notebook content from cells below '{current_cell_id}':")
print(formatted_content)

from googleapiclient.discovery import build
from google.colab import auth
from google.auth import default

# 1. Define the doc_id variable
doc_id = '1PGm7m_U2iyrfgcp6h-9t9dNs0FG9QOmmdh1qdhn1O9Q'

# Authenticate and build the service
auth.authenticate_user()
creds, _ = default()
service = build('docs', 'v1', credentials=creds)

# 2. Get the current content of the Google Doc
doc = service.documents().get(documentId=doc_id).execute()
content = doc.get('body', {}).get('content', [])

# Extract and store the text content
document_text = ""
for element in content:
    if 'paragraph' in element:
        for elem in element['paragraph'].get('elements', []):
            text = elem.get('textRun', {}).get('content', '')
            document_text += text

print("\nContent retrieved from Google Doc:")
print(document_text)

# Markers
begin_marker = "BEGIN COLAB EXPORT"
end_marker = "END COLAB EXPORT"

requests = []

# Clear all existing content in the document, excluding the final newline
if content:
    requests.append({
        'deleteContentRange': {
            'range': {
                'startIndex': 1,
                'endIndex': content[-1]['endIndex'] -1 # Exclude the last character
            }
        }
    })


# Insert the BEGIN COLAB EXPORT, the formatted content, and the END COLAB EXPORT markers at the beginning of the document.
requests.append({
    'insertText': {
        'location': {'index': 1},
        'text': f"{begin_marker}\n{formatted_content}\n{end_marker}\n"
    }
})


# 6. Execute the prepared requests
if requests:
    service.documents().batchUpdate(documentId=doc_id, body={'requests': requests}).execute()
    print(f"Content written to Google Doc with ID: {doc_id}")
# Out:
# Exporting notebook content from cells below 'pT_a8Zm8NbBM':
# Markdown Cell 5:
# # printing md
#
# Code Cell 6:
# ```python
# from rich.console import Console
# from rich.markdown import Markdown
# import math
#
# console = Console()
#
# markdown_text = """
# """
#
# md = Markdown(markdown_text)
# console.print(md)
# def pp(*args, **kwargs):
#   console.print(Markdown(*args, **kwargs))
# pp("""h""")
# ```
# Output:
# ```
# ...

# %% [markdown]
# # printing md

# %%
from rich.console import Console
from rich.markdown import Markdown
import math

console = Console()

markdown_text = """
"""

md = Markdown(markdown_text)
console.print(md)
def pp(*args, **kwargs):
  console.print(Markdown(*args, **kwargs))
pp("""h""")
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# h

# %% [markdown]
# # ====================

# %% [markdown]
# ## 2.4 Numeric types: Floating-point
#
# ### Floating-point numbers and scientific notation
#
# A floating-point number is a real number, like 98.6, 0.0001, or -666.667. The term "floating-point" refers to the decimal point appearing anywhere ("floating") in the number. Thus, float is a data type for floating-point numbers.
#
# A floating-point literal is written with the fractional part even if that fraction is 0, as in 1.0, 0.0, or 99.0.
#
# ##
#
# Figure 2.4.1: A program using float-type variables.
#
# The following program reads in a floating-point value from a user and calculates the time to drive and fly the distance. Note the use of the built-in function float() when reading the input to convert the input string into a float.
#
# Note that print handles floating-point numbers straightforwardly.
#
# miles \= float(input("Enter a distance in miles: "))
# hours\_to\_fly \= miles / 500.0
# hours\_to\_drive \= miles / 60.0
#
# print(miles, "miles would take:")
# print(hours\_to\_fly, "hours to fly")
# print(hours\_to\_drive, "hours to drive")
#
# Enter a distance in miles: 450
# 450.0 miles would take:
# 0.9 hours to fly
# 7.5 hours to drive
# ...
# Enter a distance in miles: 1800
# 1800.0 miles would take:
# 3.6 hours to fly
# 30.0 hours to drive
#
# Feedback?
#
# Scientific notation is useful for representing floating-point numbers that are much greater than or much less than 0, such as 6.02×1023. A floating-point literal using scientific notation is written using an "e" preceding the power-of-10 exponent, as in 6.02e23 to represent 6.02×1023. The "e" stands for exponent. Likewise, 0.001 is 1×10−3, so it can be written as 1.0e-3.
#
# participation activity
#
# ##
#
# 2.4.1: Scientific notation.
#
# 1)
#
# Type 1.0e-4 as a floating-point literal but not using scientific notation, with a single digit before and four digits after the decimal point.
#
# Check Show answer
#
# 2)
#
# Type 7.2e-4 as a floating-point literal without using scientific notation, using a single digit before and five digits after the decimal point.
#
# Check Show answer
#
# 3)
#
# Type 540,000,000 as a floating-point literal using scientific notation with a single digit before and after the decimal point.
#
# Check Show answer
#
# 4)
#
# Type 0.000001 as a floating-point literal using scientific notation with a single digit before and after the decimal point.
#
# Check Show answer
#
# 5)
#
# Type 623.596 as a floating-point literal using scientific notation with a single digit before and five digits after the decimal point.
#
# Check Show answer
#
# Feedback?
#
# ##
#
# Try 2.4.1: Energy to mass conversion.
#
# _fullscreen_
#
# Full screen
#
# Albert Einstein's equation E\=m⁢c2 is likely the most widely known mathematical formula. The equation describes the mass-energy equivalence, which states that the mass (amount of matter) _m_ of a body is directly related to the amount of energy _E_ of the body, connected via a constant value c2, the speed of light squared. The significance of the equation is that matter can be converted to energy, (and theoretically, energy back to matter). The mass-energy equivalence equation can be used to calculate the energy released in nuclear reactions, such as nuclear fission or nuclear fusion, which form the basis of modern technologies like nuclear weapons and nuclear power plants.
#
# The following program reads in a mass in kilograms and prints the amount of energy stored in the mass. Also printed are the equivalent numbers of AA batteries and tons of TNT.
#
# Feedback?
#
# ### Overflow
#
# Float-type objects have a limited range of values that can be represented. For a standard 32-bit installation of Python, the maximum floating-point value is approximately 1.8×10308, and the minimum positive floating-point value is approximately 2.3×10−308. Assigning a floating-point value outside of this range generates an OverflowError. Overflow occurs when a value is too large to be stored in the memory allocated by the interpreter. Ex: The program in the figure below tries to store the value 2.01024, which causes an overflow error.
#
# In general, floating-point types should be used to represent quantities that are measured, such as distances, temperatures, volumes, and weights. Integer types should be used to represent quantities that are counted, such as numbers of cars, students, cities, hours, and minutes.
#
# ##
#
# Figure 2.4.2: Float can overflow.
#
# print("2.0 to the power of 256 =", 2.0\*\*256)
# print("2.0 to the power of 512 = ", 2.0\*\*512)
# print("2.0 to the power of 1024 = ", 2.0\*\*1024)
#
# 2.0 to the power of 256 = 1.15792089237e+77
# 2.0 to the power of 512 =  1.34078079299e+154
# 2.0 to the power of 1024 =
# Traceback (most recent call last):
#   File "<stdin>", line 3, in <module>
# OverflowError: (34, 'Result too large')
#
# Feedback?
#
# participation activity
#
# ##
#
# 2.4.2: Floating-point versus integer.
#
# Choose the right type for a variable to represent each item.
#
# 1)
#
# The number of cars in a parking lot.
#
# float
#
# int
#
# 2)
#
# The current temperature in Celsius.
#
# float
#
# int
#
# 3)
#
# A person's height in centimeters.
#
# float
#
# int
#
# 4)
#
# The number of hairs on a person's head.
#
# float
#
# int
#
# 5)
#
# The average number of kids per household.
#
# float
#
# int
#
# Feedback?
#
# ### Manipulating floating-point output
#
# Some floating-point numbers have many digits after the decimal point. Ex: Irrational numbers (Ex: 3.14159265359...) and repeating decimals (Ex: 4.33333333...) have an infinite number of digits after the decimal. By default, most programming languages output at least five digits after the decimal point. But for many simple programs, this level of detail is not necessary. A common approach is to output floating-point numbers with a specific number of digits after the decimal to reduce complexity or produce a certain numerical type (Ex: Representing currency with two digits after the decimal). The syntax for outputting the float my\_float with two digits after the decimal point is `print(f"{my_float:.2f}")`
#
# When outputting a certain number of digits after the decimal using print(), Python rounds the last output digit, but the floating-point value remains the same. Manipulating how numbers are output is discussed in detail elsewhere.
#
# participation activity
#
# ##
#
# 2.4.3: Reducing the output of Pi.
#
# Start
#
#  2x speed
#
# import math
#
# print("Default output of Pi:",  math.pi)
# print("Pi reduced to 4 digits after the decimal:", end\=" ")
# print(f"{math.pi:.4f}")
#
# Pi reduced to 4 digits after the decimal: 3.1416
#
# Default output of Pi: 3.141592653589793
#
# 3.141592653589793...
#
# Static figure: Begin Python code: import math print("Default output of Pi", math.pi) print("Pi reduced to 4 digits after the decimal:", end=" ") print(f"{math.pi:.4f}") End Python code. The output for the code is displayed in an output box. This is the two-line output: Default output of pi: 3.141592653589793 Pi reduced to 4 digits after the decimal: 3.1416 End output. Step 1: The mathematical constant Pi (π) is irrational. Pi is a floating-point number whose digits after the decimal point are infinite and non-repeating. The math module defines the constant pi with the value of Pi. The output display is empty. In the first line of code, "math.pi" is highlighted. The value "3.141592653589793…" appears above the highlighted variable name "math.pi". Step 2: Though Python does not attempt to output the full value of Pi, Python outputs 15 digits after the decimal by default. The line of code, "print("Default output of Pi:", math.pi)", is highlighted. Then, the text "Default output of Pi: 3.141592653589793" appears in the output display. Step 3: print(f"{math.pi:.4f}") outputs Pi to only four digits after the decimal. The last digit is rounded up in the output, but the value of Pi remains the same. The line of code, "print("Default output of Pi:", math.pi)", is no longer highlighted and the lines of code, "print("Pi reduced to 4 digits after the decimal:", end=" ")" and "print(f"{math.pi:.4f}")". The text "Pi reduced to 4 digits after the decimal: 3.1416" then appears in the output.
#
# _keyboard\_arrow\_down_
#
# Captions
#
# 1.  The mathematical constant Pi (π) is irrational. Pi is a floating-point number whose digits after the decimal point are infinite and non-repeating. The math module defines the constant pi with the value of Pi.
# 2.  Though Python does not attempt to output the full value of Pi, Python outputs 15 digits after the decimal by default.
# 3.  print(f"{math.pi:.4f}") outputs Pi to only four digits after the decimal. The last digit is rounded up in the output, but the value of Pi remains the same.
#
# Feedback?
#
# participation activity
#
# ##
#
# 2.4.4: Reducing floating-point output.
#
# 1)
#
# Which of the following arguments completes print() to output two digits after the decimal point?
# `print(f"{(7.0 / 3.0)_____)`
#
# .2f}"
#
# 2:f}"
#
# :.2f}"
#
# 2)
#
# What is output by `print(f"{0.125:.1f}")`?
#
# 0
#
# 0.1
#
# 0.13
#
# 3)
#
# What is output by `print(f"{9.1357:.3f}")`?
#
# 9.136
#
# 9.135
#
# 9.14
#
# Feedback?
#
# challenge activity
#
# ##
#
# 2.4.1: Gallons of paint needed to paint walls.
#
# The number of gallons of paint needed to cover a wall is equal to the wall's total area divided by 350.0. The program reads wall\_area from input, representing a wall's total area. Then, the program computes num\_gallons as wall\_area / 350.0.
#
# Complete the program to output the number of gallons of paint needed to cover the wall, rounded to five digits after the decimal point.
#
# **Click here for examples**
#
# Ex 1: If variable wall\_area is assigned the value `250.0` read from input, then the output is:
#
# 0.71429
#
# Ex 2: If variable wall\_area is assigned the value `10578.6` read from input, then the output is:
#
# 30.22457
#
# Note: `print(f"{my_float:.Xf}")` outputs my\_float to X digits after the decimal point.
#
#
#
#
# See [How to Use zyBooks](https://learn.zybooks.com/zybook/HowToUsezyBooks2/70d49b1b-63ca-586d-e3cd-417eba845c6f) for info on how our automated program grader works.
#
# 712910.5105864.qx3zqy7
#
# 1
#
# 2
#
# 3
#
# 4
#
# 5
#
# 6
#
# 7
#
# 8
#
# \# Assign wall\_area with a float read from input
#
# wall\_area \= float(input())
#
# \# Compute num\_gallons
#
# num\_gallons \= wall\_area / 350.0
#
# """ Your solution goes here """
#
#
#
#
#
# 1 test passed
#
# All tests passed
#
# Run
#
# Feedback?
#
# challenge activity
#
# ##
#
# 2.4.2: Numeric types: Floating-point.
#
# 712910.5105864.qx3zqy7
#
# Start
#
# One minute equals 60 seconds. The following program intends to read a floating-point value from input and output the quantity in minutes, but the code contains an error when reading from input. Find and fix the error.
#
# Ex: If the input is `3.2`, then the output is:
#
# `0.053 minutes`
#
# 1
#
# 2
#
# 3
#
# 4
#
# 5
#
# 6
#
# \# Modify the following line of code
#
# length\_secs \= input()
#
# length\_mins \= length\_secs / 60
#
# print(f"{length\_mins:.3f} minutes")
#
#
#
#
#
# 1
#
# 2
#
# 3
#
# 4
#
# Check Next level
#
# 1
#
# 2
#
# 3
#
# 4
#
# Feedback?
#
# How was this section?
#
# _thumb\_up_
#
# |
#
# _thumb\_down_
#
# Provide section feedback
#
# Activity summary for assignment: C2Lec
#
# 45 / 189 points
#
# Due: 02/12/2026, 11:59 PM PST
#
# _keyboard\_arrow\_up_
#
# Completion details
#
# [
#
# Section 2.1
#
# ](https://learn.zybooks.com/zybook/CPPCS2520NguyenSpring2026/chapter/2/section/1)30 / 30 points
#
# _keyboard\_arrow\_down_
#
# Participation activities
#
# 2.1.1 1 / 1 point 2.1.2 1 / 1 point 2.1.3 5 / 5 points 2.1.4 3 / 3 points 2.1.5 1 / 1 point 2.1.6 4 / 4 points
#
# Challenge activities
#
# 2.1.1 6 / 6 points 2.1.2 5 / 5 points 2.1.3 4 / 4 points
#
# [
#
# Section 2.2
#
# ](https://learn.zybooks.com/zybook/CPPCS2520NguyenSpring2026/chapter/2/section/2)11 / 11 points
#
# _keyboard\_arrow\_down_
#
# Participation activities
#
# 2.2.1 10 / 10 points 2.2.2 1 / 1 point
#
# [
#
# Section 2.3
#
# ](https://learn.zybooks.com/zybook/CPPCS2520NguyenSpring2026/chapter/2/section/3)4 / 4 points
#
# _keyboard\_arrow\_down_
#
# Participation activities
#
# 2.3.1 1 / 1 point 2.3.2 1 / 1 point 2.3.3 2 / 2 points
#
# [
#
# Section 2.4
#
# ](https://learn.zybooks.com/zybook/CPPCS2520NguyenSpring2026/chapter/2/section/4)0 / 20 points
#
# _keyboard\_arrow\_up_
#
# Participation activities
#
# 2.4.1 0 / 5 points 2.4.2 0 / 5 points 2.4.3 0 / 1 point 2.4.4 0 / 3 points
#
# Challenge activities
#
# 2.4.1 0 / 2 points 2.4.2 0 / 4 points
#
# [Next section](https://learn.zybooks.com/zybook/CPPCS2520NguyenSpring2026/chapter/2/section/5)
#
# [
#
# Section 2.5
#
# ](https://learn.zybooks.com/zybook/CPPCS2520NguyenSpring2026/chapter/2/section/5)0 / 32 points
#
# _keyboard\_arrow\_down_
#
# Participation activities
#
# 2.5.1 0 / 7 points 2.5.2 0 / 6 points 2.5.3 0 / 1 point 2.5.4 0 / 6 points 2.5.5 0 / 1 point
#
# Challenge activities
#
# 2.5.1 0 / 5 points 2.5.2 0 / 6 points
#
# [
#
# Section 2.6
#
# ](https://learn.zybooks.com/zybook/CPPCS2520NguyenSpring2026/chapter/2/section/6)0 / 14 points
#
# _keyboard\_arrow\_down_
#
# Participation activities
#
# 2.6.1 0 / 2 points 2.6.2 0 / 4 points 2.6.3 0 / 4 points 2.6.4 0 / 1 point
#
# Challenge activities
#
# 2.6.1 0 / 3 points
#
# [
#
# Section 2.7
#
# ](https://learn.zybooks.com/zybook/CPPCS2520NguyenSpring2026/chapter/2/section/7)0 / 20 points
#
# _keyboard\_arrow\_down_
#
# Participation activities
#
# 2.7.1 0 / 4 points 2.7.2 0 / 6 points 2.7.3 0 / 4 points
#
# Challenge activities
#
# 2.7.1 0 / 3 points 2.7.2 0 / 3 points
#
# [
#
# Section 2.8
#
# ](https://learn.zybooks.com/zybook/CPPCS2520NguyenSpring2026/chapter/2/section/8)0 / 6 points
#
# _keyboard\_arrow\_down_
#
# Participation activities
#
# 2.8.1 0 / 1 point 2.8.2 0 / 1 point 2.8.3 0 / 1 point 2.8.4 0 / 2 points
#
# Challenge activities
#
# 2.8.1 0 / 1 point
#
# [
#
# Section 2.9
#
# ](https://learn.zybooks.com/zybook/CPPCS2520NguyenSpring2026/chapter/2/section/9)0 / 15 points
#
# _keyboard\_arrow\_down_
#
# Participation activities
#
# 2.9.1 0 / 5 points
#
# Challenge activities
#
# 2.9.1 0 / 5 points 2.9.2 0 / 1 point 2.9.3 0 / 4 points
#
# [
#
# Section 2.10
#
# ](https://learn.zybooks.com/zybook/CPPCS2520NguyenSpring2026/chapter/2/section/10)0 / 21 points
#
# _keyboard\_arrow\_down_
#
# Participation activities
#
# 2.10.1 0 / 2 points 2.10.2 0 / 1 point 2.10.3 0 / 5 points 2.10.4 0 / 1 point 2.10.5 0 / 6 points 2.10.6 0 / 3 points 2.10.7 0 / 3 points
#
# [
#
# Section 2.11
#
# ](https://learn.zybooks.com/zybook/CPPCS2520NguyenSpring2026/chapter/2/section/11)0 / 16 points
#
# _keyboard\_arrow\_down_
#
# Participation activities
#
# 2.11.1 0 / 1 point 2.11.2 0 / 3 points 2.11.3 0 / 1 point 2.11.4 0 / 1 point 2.11.5 0 / 2 points
#
# Challenge activities
#
# 2.11.1 0 / 5 points 2.11.2 0 / 3 points
#
# [
#
# Section 2.12
#
# ](https://learn.zybooks.com/zybook/CPPCS2520NguyenSpring2026/chapter/2/section/12)
#
# _keyboard\_arrow\_down_
#
# Reading only
#
# [
#
# Section 2.13
#
# ](https://learn.zybooks.com/zybook/CPPCS2520NguyenSpring2026/chapter/2/section/13)
#
# _keyboard\_arrow\_down_
#
# Reading only
#
# [_arrow\_downward_](https://learn.zybooks.com/zybook/CPPCS2520NguyenSpring2026/chapter/2/section/5)

# %% [markdown]
# ### Figure 2.4.1: A program using float-type variables.

# %% [markdown]
# ### 2.4.1: Scientific notation.

# %%
''' convert 1.0e-4 as a floating-point literal but not using scientific notation, with a single digit before and four digits after the decimal point.'''
print(f"{1.0e-4:.4f}")
# Out:
# 0.0001

# %%
'''
Type 7.2e-4 as a floating-point literal without using scientific notation, using a single digit before and five digits after the decimal point.'''
print(f"{7.2e-4:.5f}")
# Out:
# 0.00072

# %%
'''Type 540,000,000 as a floating-point literal using scientific notation with a single digit before and after the decimal point.'''
print(f"{540000000:.1e}")
###
n = 540000000

s = f"{n:.1e}"          # "5.4e+08"
s = s.replace("e+0", "e").replace("e+", "e")  # "5.4e8"
print(s)
###
import math

n = 540000000
exp = int(math.floor(math.log10(abs(n))))
mant = n / (10 ** exp)
print(f"{mant:.1f}e{exp}")   # 5.4e8
###
# Out:
# 5.4e+08
# 5.4e8
# 5.4e8

# %%
'''
Type 0.000001 as a floating-point literal using scientific notation with a single digit before and after the decimal point.
'''

# This produces 1.0e-06
print(f"{0.000001:.1e}")

# To get 1.0e-6, we can replace the 'e-0' with 'e-'
formatted_scientific = f"{0.000001:.1e}"
corrected_scientific = formatted_scientific.replace('e-0', 'e-')
print(corrected_scientific)
# Out:
# 1.0e-06
# 1.0e-6

# %%
'''Type 623.596 as a floating-point literal using scientific notation with a single digit before and five digits after the decimal point.
'''
print(f"{623.596:.5e}")
###
n = 623.596

s = f"{n:.5e}"          # "5.4e+08"
s = s.replace("e+0", "e").replace("e+", "e")  # "5.4e8"
print(s)
###
# Out:
# 6.23596e+02
# 6.23596e2

# %% [markdown]
# ### Try 2.4.1: Energy to mass conversion.

# %%
c_meters_per_sec = 299792458  # Speed of light (m/s)
joules_per_AA_battery = 4320.5  # Nickel-Cadmium AA batteries
joules_per_TNT_ton = 4.184e9

# Read in a floating-point number from the user
mass_kg = float(input())

# Compute E = mc^2.
energy_joules = mass_kg * (c_meters_per_sec**2)  # E = mc^2
print("Total energy released:", energy_joules, "Joules")

# Calculate equivalent number of AA and tons of TNT.
num_AA_batteries = energy_joules / joules_per_AA_battery
num_TNT_tons = energy_joules / joules_per_TNT_ton

print("Which is as much energy as:")
print("  ", num_AA_batteries, "AA batteries")
print("  ", num_TNT_tons, "tons of TNT")
# Out:
# 10
# Total energy released: 8.987551787368177e+17 Joules
# Which is as much energy as:
#    208021103746514.9 AA batteries
#    214807643.10153386 tons of TNT

# %% [markdown]
# ### Figure 2.4.2: Float can overflow.

# %%
'''print("2.0 to the power of 256 =", 2.0**256)
print("2.0 to the power of 512 = ", 2.0**512)
print("2.0 to the power of 1024 = ", 2.0**1024)'''


print("2.0 to the power of 256 =", 2.0**256)
print("2.0 to the power of 512 = ", 2.0**512)

try:
    print("2.0 to the power of 1024 = ", 2.0**1024)
except OverflowError:
    print("❌❌❌2.0 to the power of 1024 = Result too large (OverflowError caught).❌❌❌")
# Out:
# 2.0 to the power of 256 = 1.157920892373162e+77
# 2.0 to the power of 512 =  1.3407807929942597e+154
# ❌❌❌2.0 to the power of 1024 = Result too large (OverflowError caught).❌❌❌

# %% [markdown]
# ### 2.4.2: Floating-point versus integer.

# %% [markdown]
# ### Choose the right type for a variable to represent each item.
#
# 1)
#
# The number of cars in a parking lot.
#
# float
#
# int
#
# ### Correct
#
# Cars are countable in whole numbers: 1 car, 2 cars, 3 cars, etc.
#
# 2)
#
# The current temperature in Celsius.
#
# float
#
# int
#
# ### Correct
#
# Temperature is a measurement that contains a decimal point.
#
# 3)
#
# A person's height in centimeters.
#
# float
#
# int
#
# ### Correct
#
# Height is a measurement that contains a decimal point.
#
# 4)
#
# The number of hairs on a person's head.
#
# float
#
# int
#
# ### Correct
#
# There are a lot (hopefully) of hairs, but still countable as whole numbers: 1 hair, 2 hairs, etc.
#
# 5)
#
# The average number of kids per household.
#
# float
#
# int
#
# ### Correct
#
# Nobody has exactly 2.2 kids, but the average almost certainly should involve a fraction.

# %% [markdown]
# ### 2.4.3: Reducing the output of Pi.

# %%
import math

print("Default output of Pi:",  math.pi)
print("Pi reduced to 4 digits after the decimal:", end=" ")
print(f"{math.pi:.4f}")
# Out:
# Default output of Pi: 3.141592653589793
# Pi reduced to 4 digits after the decimal: 3.1416

# %% [markdown]
# ### 2.4.4: Reducing floating-point output.

# %%
print(f"{(7.0/3.0):.2f}")
# Out:
# 2.33

# %%
print(f"{0.125:.1f}")
# Out:
# 0.1

# %%
 print(f"{9.1357:.3f}")
# Out:
# 9.136

# %% [markdown]
# ### 2.4.1: Gallons of paint needed to paint walls.

# %%
# Assign wall_area with a float read from input
wall_area = float(input())

# Compute num_gallons
num_gallons = wall_area / 350.0

""" Your solution goes here """
print(f"{num_gallons:.5f}")
# Out:
# 250
# 0.71429

# %%
# Modify the following line of code
length_secs = float(input())


length_mins = length_secs / 60

print(f"{length_mins:.3f} minutes")
# Out:
# 90
# 1.500 minutes

# %%
"""The surface area of a cube is given by cube_area = 6 * cube_side^2.
. Read cube_side from input as a float. Then, compute cube_area using the formula.

Ex: If the input is 3.60, then the output is:

77.76

Note: ''cube_side^2 ''can be computed using cube_side * cube_side.


"""

""" Your code goes here """
cube_side = float(input())
cube_area = 6 * cube_side * cube_side
print(f"{cube_area:.2f}")
# Out:
# 12
# 864.00

# %%
"""Complete the program to output the value of vol_pints to three digits after the decimal point, followed by " pints".

Ex: If the input is 48.0, then the output is:

3.000 pints
Note: print(f"{my_float:.Xf}") outputs my_float to X digits after the decimal point."""

vol_ounces = float(input())
vol_pints = vol_ounces / 16

""" Your code goes here """
print(f"{vol_pints:.3f} pints")
# Out:
# 60
# 3.750 pints

# %%
from rich.console import Console
from rich.markdown import Markdown
import math

console = Console()

markdown_text = """
---
# 2.4.2: Numeric types: Floating-point. (3)
---
Complete the program as follows:

1.  Read cylinder_height and cylinder_radius from input as floats, respectively.
2.  Compute cylinder_volume using the formula c⁢y⁢l⁢i⁢n⁢d⁢e⁢r_v⁢o⁢l⁢u⁢m⁢e=π∗c⁢y⁢l⁢i⁢n⁢d⁢e⁢r_h⁢e⁢i⁢g⁢h⁢t∗c⁢y⁢l⁢i⁢n⁢d⁢e⁢r_r⁢a⁢d⁢i⁢u⁢s2.
3.  Output "Cylinder volume is " followed by the value of cylinder_volume to five digits after the decimal point.

Ex: If the input is:

```
5.0
3.0
```

then the output is:

`Cylinder volume is 141.37167`

Note:

-   Use math.pi for π.
-   c⁢y⁢l⁢i⁢n⁢d⁢e⁢r_r⁢a⁢d⁢i⁢u⁢s2 can be computed using *.

---
"""

md = Markdown(markdown_text)
console.print(md)


import math

""" Your code goes here """
cylinder_height = float(input())
cylinder_radius = float(input())

cylinder_volume = math.pi * cylinder_height * (cylinder_radius * cylinder_radius)

print(f"Cylinder volume is {cylinder_volume:.5f}")
# Out:
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                    2.4.2: Numeric types: Floating-point. (3)                                    ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Complete the program as follows:
#
#  1 Read cylinder_height and cylinder_radius from input as floats, respectively.
#  2 Compute cylinder_volume using the formula c⁢y⁢l⁢i⁢n⁢d⁢e⁢r_v⁢o⁢l⁢u⁢m⁢e=π∗c⁢y⁢l⁢i⁢n⁢d⁢e⁢r_h⁢e⁢i⁢g⁢h⁢t∗c⁢y⁢l⁢i⁢n⁢d⁢e⁢r_r⁢a⁢d⁢i⁢u⁢s2.
#  3 Output "Cylinder volume is " followed by the value of cylinder_volume to five digits after the decimal point.
#
# Ex: If the input is:
#
#
#  5.0
# ...

# %% [markdown]
# # ====================

# %% [markdown]
# # 2.5 Arithmetic expressions
#
# ### Basics
#
# An expression is a combination of items, like variables, literals, operators, and parentheses, that evaluates to a value, like 2 \* (x + 1). A common place where expressions are used is on the right side of an assignment statement, as in y = 2 \* (x + 1).
#
# A literal is a specific value in code like 2. An operator is a symbol that performs a built-in calculation, like +, which performs addition. Common programming operators are shown below.
#
# ##
#
# Table 2.5.1: Arithmetic operators.
#
# | Arithmetic operator | Description |
# | --- | --- |
# | +   | The addition operator is +, as in x + y. |
# | \\- | The subtraction operator is \\-, as in x - y. Also, the - operator is for negation, as in -x + y, or x + -y. |
# | \\* | The multiplication operator is \\*, as in x \\* y. |
# | /   | The division operator is /, as in x / y. |
# | \\*\\* | The exponent operator is \\*\\*, as in x \\*\\* y (x to the power of y). |
#
# Feedback?
#
# participation activity
#
# ##
#
# 2.5.1: Expressions.
#
# Indicate which are valid expressions. x and y are variables.
#
# 1)
#
# x + 1
#
# Valid
#
# Not valid
#
# 2)
#
# 2 \* (x - y)
#
# Valid
#
# Not valid
#
# 3)
#
# x
#
# Valid
#
# Not valid
#
# 4)
#
# 2
#
# Valid
#
# Not valid
#
# 5)
#
# 2x
#
# Valid
#
# Not valid
#
# 6)
#
# 2 + (xy)
#
# Valid
#
# Not valid
#
# 7)
#
# y = x + 1
#
# Valid
#
# Not valid
#
# Feedback?
#
# participation activity
#
# ##
#
# 2.5.2: Capturing behavior with an expression.
#
# Does the expression correctly capture the intended behavior?
#
# 1)
#
# 6 plus num\_items:
#
# `6 + num_items`
#
# Yes
#
# No
#
# 2)
#
# 6 times num\_items:
#
# `6 x num_items`
#
# Yes
#
# No
#
# 3)
#
# total\_days divided by 12:
#
# `total_days / 12`
#
# Yes
#
# No
#
# 4)
#
# 5 times t:
#
# `5t`
#
# Yes
#
# No
#
# 5)
#
# The negative of user\_val:
#
# `-user_val`
#
# Yes
#
# No
#
# 6)
#
# n factorial
#
# `n!`
#
# Yes
#
# No
#
# Feedback?
#
# ### Evaluation of expressions
#
# An expression evaluates to a value, which replaces the expression. Ex: If x is 5, then x + 1 evaluates to 6, and y = x + 1 assigns y with 6.
#
# An expression is evaluated using the order of standard mathematics, and is also known in programming as precedence rules, listed below.
#
# ##
#
# Table 2.5.2: Precedence rules for arithmetic operators.
#
# | Operator/Convention | Description | Explanation |
# | --- | --- | --- |
# | **( )** | Items within parentheses are evaluated first. | In 2 \\* (x + 1), the x + 1 is evaluated first, with the result then multiplied by 2. |
# | **exponent \\*\\*** | \\*\\* used for exponent is next. | In x\\*\\*y \\* 3, x to the power of y is computed first, with the results then multiplied by 3. |
# | **unary -** | \\- used for negation (unary minus) is next. | In 2 \\* -x, the -x is computed first, with the result then multiplied by 2. |
# | **\\* / %** | Next to be evaluated are \\*, /, and %, having equal precedence. | (% is discussed elsewhere.) |
# | **\\+ -** | Finally come + and - with equal precedence. | In y = 3 + 2 \\* x, the 2 \\* x is evaluated first, with the result then added to 3, because \\* has higher precedence than +. Spacing doesn't matter because y = 3+2 \\* x would still evaluate 2 \\* x first. |
# | **left-to-right** | If more than one operator of equal precedence could be evaluated, evaluation occurs left to right. Note: The \\*\\* operator is evaluated from right-to-left. | In y = x \\* 2 / 3, the x \\* 2 is first evaluated, with the result then divided by 3. |
#
# Feedback?
#
# participation activity
#
# ##
#
# 2.5.3: Evaluating expressions.
#
# Start
#
#  2x speed
#
# y =
#
# 3 \* (x + 10 / w)
#
# x = 4
#
# w = 2
#
# 5
#
# 3 \* (x + 5)
#
# 3 \* 9
#
# 27
#
# 10 / 2
#
# 4 + 5
#
# 9
#
# y =
#
# y = 3 \* (x + (10 / w))
#
# Preferred
#
# Static figure: Begin math: x = 4 w = 2 y = 3 \* (x + 10 / w) 10 / 2 5 3 \* (x + 5) 4 + 5 9 3 \* 9 y = 27 End math. Under header Preferred: y = 3 \* (x + (10 / w)) End figure. Step 1: An expression such as 3 \* (x + 10 / w) evaluates to a value, using precedence rules. Items within parentheses come first, and / comes before +, yielding 3 \* (x + 5). Shown are three equations: "x = 4", "w = 2", "y = 3 \* (x + 10 / w)". Superimposed on the last equation, atop "10 / w", is the expression "10 / 2". "10 / 2" then descends from atop the equation to below the equation. The number 5 then appears below "10 / 2" and the equation "3 \* (x + 5)" appears below the number 5. Step 2: Evaluation finishes inside the parentheses: 3 \* (x + 5) becomes 3 \* 9. Below "3 \* (x + 5)" appears "4 + 5", below which "9" appears. "3 \* 9" then appears below the 9. Step 3: Thus, the original expression evaluates to 3 \* 9 or 27. That value replaces the expression. So y = 3 \* (x + 10 / w) becomes y = 27, so y is assigned with 27. "y = 27" appears below "3 \* 9". Step 4: Many programmers prefer to use parentheses to make order of evaluation more clear when the order is not obvious. "y = 3 \* (x + 10 / w)" appears to the side, "y = 3 \* (x + (10 / w))" under the header, Preffered.
#
# _keyboard\_arrow\_down_
#
# Captions
#
# 1.  An expression such as 3 \* (x + 10 / w) evaluates to a value, using precedence rules. Items within parentheses come first, and / comes before +, yielding 3 \* (x + 5).
# 2.  Evaluation finishes inside the parentheses: 3 \* (x + 5) becomes 3 \* 9.
# 3.  Thus, the original expression evaluates to 3 \* 9 or 27. That value replaces the expression. So y = 3 \* (x + 10 / w) becomes y = 27, so y is assigned with 27.
# 4.  Many programmers prefer to use parentheses to make order of evaluation more clear when the order is not obvious.
#
# Feedback?
#
# participation activity
#
# ##
#
# 2.5.4: Evaluating expressions and precedence rules.
#
# Select the expression in which parentheses match the evaluation order of the original expression.
#
# 1)
#
# y + 2 \* z
#
# (y + 2) \* z
#
# y + (2 \* z)
#
# 2)
#
# z / 2 - x
#
# (z / 2) - x
#
# z / (2 - x)
#
# 3)
#
# x \* y \* z
#
# (x \* y) \* z
#
# x \* (y \* z)
#
# 4)
#
# x + 1 \* y/2
#
# ((x + 1) \* y) / 2
#
# x + ((1 \* y) / 2)
#
# x + ( 1 \* (y / 2))
#
# 5)
#
# x / 2 + y / 2
#
# ((x / 2) + y) / 2
#
# (x / 2) + (y / 2)
#
# 6)
#
# What is total\_count after executing the following?
#
# num\_items \= 5
# total\_count \= 1 + (2 \* num\_items)  \* 4
#
# 44
#
# 41
#
# Feedback?
#
# challenge activity
#
# ##
#
# 2.5.1: Precedence rules for arithmetic operators.
#
# 712910.5105864.qx3zqy7
#
#
#
# Start Jump to level 1
#
# Which operator is evaluated first?
#
# c + f / 25
#
# Select one + /
#
# 1
#
# 2
#
# 3
#
# 4
#
# 5
#
# Check
#
# Next
#
# Try again
#
# question\_mark signifies a specific hint for an answer
#
# Show solution
#
# **Done**. Click any level to practice more. Completion is preserved.
#
# ✖ ![Correct](https://zytools.zybooks.com/zyBooks2/fingerprinted/989bd345-53bb-496c-85f2-cbd4a9e1c55b/utilities/resource/checkmark.png)
#
# Solution
#
# 1
#
# 2
#
# 3
#
# 4
#
# 5
#
# Feedback?
#
# ##
#
# Using parentheses to make the order of evaluation explicit
#
# A common error is to omit parentheses and assume an incorrect order of evaluation, leading to a bug. Ex: If x is 3, then 5 \* x+1 might appear to evaluate as 5 \* (3+1) or 20, but actually evaluates as (5 \* 3) + 1 or 16 (spacing doesn't matter). Good practice is to use parentheses to make order of evaluation explicit, rather than relying on precedence rules, as in: y = (m \* x) + b, unless order doesn't matter as in x + y + z.
#
# ### Example: Calorie expenditure
#
# A website lists the calories expended by men and women during exercise as follows ([Formula for Calories Burned](https://web.archive.org/web/20120422154143/http://fitnowtraining.com/2012/01/formula-for-calories-burned/)):
#
# Men: Calories = \[(Age × 0.2017) + (Weight × 0.09036) + (Heart Rate × 0.6309) — 55.0969\] × Time / 4.184
#
# Women: Calories = \[(Age × 0.074) — (Weight × 0.05741) + (Heart Rate × 0.4472) — 20.4022\] × Time / 4.184
#
# Below are those expressions written using programming notation:
#
# calories\_man = ( (age\_years \* 0.2017) + (weight\_pounds \* 0.09036) + (heart\_bpm \* 0.6309) - 55.0969 ) \* time\_minutes / 4.184
#
# calories\_woman = ( (age\_years \* 0.074) - (weight\_pounds \* 0.05741) + (heart\_bpm \* 0.4472) - 20.4022 ) \* time\_minutes/ 4.184
#
# participation activity
#
# ##
#
# 2.5.5: Converting a formatted expression to a program expression.
#
# Consider the example above. Match the changes that were made.
#
# How to use this tool
#
# Mouse: Drag/drop
# Keyboard: Grab/release Spacebar (or Enter). Move ↑↓←→. Cancel Esc
#
# \[ \]
#
# ×
#
# Spaces in variable names
#
# —
#
# * * *
#
# Replaced by ( )
#
# Underscores
#
# \-
#
# \*
#
# Reset
#
# Feedback?
#
# challenge activity
#
# ##
#
# 2.5.2: Calculate the values of the integer expressions.
#
# 712910.5105864.qx3zqy7
#
#
#
# Start Jump to level 1
#
# Type the program's output
#
# | - main.py x = 17 y = x + 2 print(y) | Input Output |
# | --- | --- |
#
# 1
#
# 2
#
# 3
#
# 4
#
# 5
#
# 6
#
# Check
#
# Next
#
# Try again
#
# question\_mark signifies a specific hint for an answer
#
# Show solution
#
# **Done**. Click any level to practice more. Completion is preserved.
#
# ✖ ![Correct](https://zytools.zybooks.com/zyBooks2/fingerprinted/989bd345-53bb-496c-85f2-cbd4a9e1c55b/utilities/resource/checkmark.png)
#
# Solution
#
# 1
#
# 2
#
# 3
#
# 4
#
# 5
#
# 6
#
# Feedback?
#
# How was this section?
#
# _thumb\_up_
#
# |
#
# _thumb\_down_
#
# Provide section feedback

# %% [markdown]
# ### 2.5.1: Expressions.

# %%
import random

x=random.randint(1,10)
y=random.randint(1,10)
print([x,y])
x + 1
# Out:
# [1, 10]
# 2

# %%
import random

x=random.randint(1,10)
y=random.randint(1,10)
print([x,y])
2*(x-y)
# Out:
# [4, 4]
# 0

# %%
import random

x=random.randint(1,10)
y=random.randint(1,10)
print([x,y])
x
# Out:
# [10, 5]
# 10

# %%
import random

x=random.randint(1,10)
y=random.randint(1,10)
print([x,y])
2
# Out:
# [10, 8]
# 2

# %%
import random

x=random.randint(1,10)
y=random.randint(1,10)
print([x,y])
2x
# Out:
#   File "/tmp/ipython-input-3167077851.py", line 6
#     2x
#     ^
# SyntaxError: invalid decimal literal

# %%
import random

x=random.randint(1,10)
y=random.randint(1,10)
print([x,y])
2 + (xy)
# Out:
# [7, 1]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3483917099.py in <cell line: 0>()
#       4 y=random.randint(1,10)
#       5 print([x,y])
# ----> 6 2 + (xy)
#
# NameError: name 'xy' is not defined

# %%
import random

x=random.randint(1,10)
y=random.randint(1,10)
print([x,y])
temp=y = x + 1
temp
print("this is wrong")
# Out:
# [4, 7]
# this is wrong

# %% [markdown]
# ## 2.5.2: Capturing behavior with an expression.
#
# ```import random
# num_items=random.randint(1,10)
# total_days=random.randint(1,10)
# t=random.randint(1,10)
# user_val=random.randint(1,10)
# n=random.randint(1,10)
# print([num_items,total_days,t,user_val,n])
# ```

# %%
import random
num_items=random.randint(1,10)
total_days=random.randint(1,10)
t=random.randint(1,10)
user_val=random.randint(1,10)
n=random.randint(1,10)
print([num_items,total_days,t,user_val,n])
# Out:
# [8, 10, 8, 5, 1]

# %%
6 + num_items
# Out:
# 14

# %%
6 x num_items
# Out:
#   File "/tmp/ipython-input-1775855062.py", line 1
#     6 x num_items
#       ^
# SyntaxError: invalid syntax

# %%
total_days / 12

# %%
total_days / 12
# Out:
# 0.8333333333333334

# %%
5t
# Out:
#   File "/tmp/ipython-input-3478359325.py", line 1
#     5t
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# # 2.5.3: Evaluating expression

# %%
x=4
w=2
y=3*(x+10/w)
[x,w,y]

print("""
y = 3 * (x + 10 / w)
1.

10 / w

2.

3 * (x + 5)

3.

3 * 9
""")
# Out:
# y = 3 * (x + 10 / w)
# 1.
#
# 10 / w
#
# 2.
#
# 3 * (x + 5)
#
# 3.
#
# 3 * 9

# %% [markdown]
# ### 2.5.4: Evaluating expressions and precedence rules.

# %%
import random
y=random.randint(1,10)
z=random.randint(1,10)
def p(*args, **kwargs):
    print(*args, **kwargs)
p([y,z])

p(y + 2 * z == y + (2 * z) )
p(z / 2 - x == (z / 2) - x )
p(x * y * z == (x * y) * z)
p(x + 1 * y/2 == x + ((1 * y) / 2))
p(x / 2 + y / 2 == (x / 2) + (y / 2) )
num_items = 5
total_count = 1 + (2 * num_items)  * 4
p(total_count)
# Out:
# [4, 4]
# True
# True
# True
# True
# True
# 41

# %% [markdown]
# ### challenge activity 2.5.1: Precedence rules for arithmetic operators.

# %%
from rich.console import Console
from rich.markdown import Markdown
import math

console = Console()

markdown_text = """
---
#
2.5.1: Precedence rules for arithmetic operators.
---
Jump to level 1

Which operator is evaluated first?

a - (d + 4) / g

Which operator is evaluated second?

Which operator is evaluated third?

Select one **+** \- /

Select one + \- **/**

Select one + **-** /



Expected: +, /, - Parentheses have the highest precedence, so + is evaluated first. Multiply and divide operations have precedence over add and subtract, so / is evaluated second. Lastly, - is evaluated.

Feedback?


---
"""

md = Markdown(markdown_text)
console.print(md)
# Out:
# <>:22: SyntaxWarning: invalid escape sequence '\-'
# <>:22: SyntaxWarning: invalid escape sequence '\-'
# /tmp/ipython-input-388800830.py:22: SyntaxWarning: invalid escape sequence '\-'
#   Select one **+** \- /
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                                                                 ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
#
#                                  2.5.1: Precedence rules for arithmetic operators.
#
# Jump to level 1
#
# Which operator is evaluated first?
#
# a - (d + 4) / g
#
# Which operator is evaluated second?
#
# Which operator is evaluated third?
#
# Select one + - /
#
# Select one + - /
#
# Select one + - /
#
# ...

# %% [markdown]
# ### 2.5.5: Converting a formatted expression to a program expression.

# %%
##
from rich.console import Console
from rich.markdown import Markdown
import math

console = Console()

markdown_text ="""### Example: Calorie expenditure

A website lists the calories expended by men and women during exercise as follows ([Formula for Calories Burned](https://web.archive.org/web/20120422154143/http://fitnowtraining.com/2012/01/formula-for-calories-burned/)):

Men: Calories = \[(Age × 0.2017) + (Weight × 0.09036) + (Heart Rate × 0.6309) — 55.0969\] × Time / 4.184

Women: Calories = \[(Age × 0.074) — (Weight × 0.05741) + (Heart Rate × 0.4472) — 20.4022\] × Time / 4.184

Below are those expressions written using programming notation:

calories\_man = ( (age\_years \* 0.2017) + (weight\_pounds \* 0.09036) + (heart\_bpm \* 0.6309) - 55.0969 ) \* time\_minutes / 4.184

calories\_woman = ( (age\_years \* 0.074) - (weight\_pounds \* 0.05741) + (heart\_bpm \* 0.4472) - 20.4022 ) \* time\_minutes/ 4.184

participation activity

##

2.5.5: Converting a formatted expression to a program expression.

Consider the example above. Match the changes that were made.

How to use this tool

Mouse: Drag/drop
Keyboard: Grab/release Spacebar (or Enter). Move ↑↓←→. Cancel Esc

* * *

\[ \]

Replaced by ( )

* * *

In mathematics, subexpressions may be enclosed in parentheses ( ), by brackets \[ \], or even by braces { } to improve readability. In programming, only parentheses are allowed. Brackets and braces are typically used for other purposes in programs.

### Correct

Spaces in variable names

Underscores

* * *

Informally, quantities may be represented with multiple words, as in Heart Rate. In a program, a variable's name must be one word, as in heart\_rate. Above, the programmer used heart\_bpm to indicate beats per minute for the rate.

### Correct

—

\-

* * *

In mathematics, minus is often written using a wide segment known as an emdash: —. However, in programming, only the hyphen symbol - may be used, since that character exists on a keyboard.

### Correct

×

\*

* * *

In mathematics, the symbol for multiplication is usually × or a dot, as in a × y, or a · y. However, in programming, only keyboard characters may be used, so the symbol used is \*.

"""

md = Markdown(markdown_text)
console.print(md)

import random
age_years=random.randint(1,10)
heart_bpm=random.randint(1,10)
time_minutes=random.randint(1,10)
weight_pounds=random.randint(1,10)
def p(*args, **kwargs):
    print(*args, **kwargs)
p([age_years,heart_bpm,time_minutes,weight_pounds])

calories_man = ( (age_years * 0.2017) + (weight_pounds * 0.09036) + (heart_bpm * 0.6309) - 55.0969 ) * time_minutes / 4.184

calories_woman = ( (age_years * 0.074) - (weight_pounds * 0.05741) + (heart_bpm * 0.4472) - 20.4022 ) * time_minutes/ 4.184
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\['
# <>:12: SyntaxWarning: invalid escape sequence '\['
# /tmp/ipython-input-1873173159.py:12: SyntaxWarning: invalid escape sequence '\['
#   Men: Calories = \[(Age × 0.2017) + (Weight × 0.09036) + (Heart Rate × 0.6309) — 55.0969\] × Time / 4.184
#                                            Example: Calorie expenditure
#
# A website lists the calories expended by men and women during exercise as follows (]8;id=747293;https://web.archive.org/web/20120422154143/http://fitnowtraining.com/2012/01/formula-for-calories-burned/\Formula for Calories Burned]8;;\):
#
# Men: Calories = [(Age × 0.2017) + (Weight × 0.09036) + (Heart Rate × 0.6309) — 55.0969] × Time / 4.184
#
# Women: Calories = [(Age × 0.074) — (Weight × 0.05741) + (Heart Rate × 0.4472) — 20.4022] × Time / 4.184
#
# Below are those expressions written using programming notation:
#
# ...

# %% [markdown]
# ### 2.5.2: Calculate the values of the integer expressions.
#
# Type the program's output

# %%
x = 7
y = x + 2

print(y)
# Out:
# 9

# %%
x = 13
y = x - 4

print(y)
# Out:
# 9

# %%
x = 2
y = x * 7

print(y)
# Out:
# 14

# %%
x = 3
y = x ** 2

print(y)
# Out:
# 9

# %%
x = 1
y = 2 * (x + 7)

print(x, y)
# Out:
# 1 16

# %%
x = 1
y = (3 * (x + 1)) + 4

print(x, y)
# Out:
# 1 10

# %% [markdown]
# # ====================

# %% [markdown]
# ##  2.6 Python expressions
#
# ### Arithmetic expressions
#
# Below is a simple program that includes an expression involving integers.
#
# ##
#
# Figure 2.6.1: Expression example: Leasing cost.
#
# | """ Computes the total cost of leasing a car given the down payment, monthly rate, and number of months """ down\\_payment \\= int(input("Enter down payment: ")) payment\\_per\\_month \\= int(input("Enter monthly payment: ")) num\\_months \\= int(input("Enter number of months: ")) total\\_cost \\= down\\_payment + (payment\\_per\\_month \\* num\\_months) print (f"Total cost: ${total\\_cost:.2f}") | Enter down payment: 500 Enter monthly payment: 300 Enter number of months: 60 Total cost: $18500.00 |
# | --- | --- |
#
# Feedback?
#
# participation activity
#
# ##
#
# 2.6.1: Simple program with an arithmetic expression.
#
# Consider the example above.
#
# 1)
#
# Would removing the parentheses as shown below yield the same result?
#
# down\_payment + payment\_per\_month \* num\_months
#
# Yes
#
# No
#
# 2)
#
# Would using two assignment statements as below have yielded the same result?
#
# all\_months\_cost = payment\_per\_month \* num\_months
# total\_cost = down\_payment + all\_months\_cost
#
# Yes
#
# No
#
# Feedback?
#
# ### Style: Single space around operators
#
# A good practice is to include a single space around operators for readability, as in num\_items + 2, rather than num\_items+2. An exception is minus used as negative, as in: x\_coordinate = -y\_coordinate. Minus (-) used as negative is known as unary minus.
#
# participation activity
#
# ##
#
# 2.6.2: Single space around operators.
#
# Retype each statement to follow the good practice of a single space around operators.
#
# Note: If an answer is marked wrong, something differs in the spacing, spelling, capitalization, etc. This activity emphasizes the importance of such details.
#
# 1)
#
# `houses_city = houses_block *10`
#
# Check Show answer
#
# 2)
#
# `total = num1+num2+2`
#
# Check Show answer
#
# 3)
#
# `num_balls=num_balls+1`
#
# Check Show answer
#
# 4)
#
# `num_entries = (user_val+1)*2`
#
# Check Show answer
#
# Feedback?
#
# ### Compound operators
#
# Special operators called compound operators provide a shorthand way to update a variable, such as age += 1 being shorthand for age = age + 1. Other compound operators include \-=, \*=, /=, and %=.
#
# ##
#
# Table 2.6.1: Compound operators.
#
# | Compound operator | Expression with compound operator | Equivalent expression |
# | --- | --- | --- |
# | Addition assignment | `age += 1` | `age = age + 1` |
# | Subtraction assignment | `age -= 1` | `age = age - 1` |
# | Multiplication assignment | `age *= 1` | `age = age * 1` |
# | Division assignment | `age /= 1` | `age = age / 1` |
# | Modulo (operator discussed elsewhere) assignment | `age %= 1` | `age = age % 1` |
#
# Feedback?
#
# participation activity
#
# ##
#
# 2.6.3: Compound operators.
#
# 1)
#
# num\_atoms is initially 7. What is num\_atoms after:
# `num_atoms += 5`?
#
# Check Show answer
#
# 2)
#
# num\_atoms is initially 7. What is num\_atoms after:
# `num_atoms *= 2`?
#
# Check Show answer
#
# 3)
#
# Rewrite the statement using a compound operator, or type: Not possible
# `car_count = car_count / 2`
#
# Check Show answer
#
# 4)
#
# Rewrite the statement using a compound operator, or type: Not possible
# `num_items = box_count + 1`
#
# Check Show answer
#
# Feedback?
#
# ### No commas allowed
#
# Commas are not allowed in an integer literal. So 1,333,555 is written as 1333555.
#
# participation activity
#
# ##
#
# 2.6.4: Assigning an integer literal.
#
# The following code correctly assigns num\_years with an integer value of 2 billion.
#
# num\_years = 2,000,000,000
#
# True
#
# False
#
# Feedback?
#
# challenge activity
#
# ##
#
# 2.6.1: Python expressions.
#
# 712910.5105864.qx3zqy7
#
# Start
#
# The expression for the acceleration of gravity is G⁢R⁢A⁢V⁢I⁢T⁢Y∗M⁢A⁢S⁢Sd⁢i⁢s⁢t⁢a⁢n⁢c⁢e2 where:
#
# -   GRAVITY = the gravitational constant (6.673e-11).
# -   MASS = the mass of the Earth in kg (5.98e+24).
# -   distance = the distance in meters from the Earth's center, read from input into variable distance.
#
# Compute the approximate acceleration of gravity for an object above the Earth's surface. Assign acceleration with the result.
#
# **Click here for example** Ex: If the input is `6.381293e6`, then the output is:
#
#     Gravity acceleration: 9.80
#
# Note:
#
# -   The input value is a floating-point literal written in scientific notation using an "e" preceding the power-of-10 exponent. The "e" stands for exponent.
# -   Ex: 6.02e23 represents 6.02x1023, while 1.0e-3 represents 1x10\-3 or 0.001.
#
# 1
#
# 2
#
# 3
#
# 4
#
# 5
#
# 6
#
# 7
#
# 8
#
# GRAVITY \= 6.673e-11
#
# MASS \= 5.98e+24
#
# distance \= float(input())
#
# """ Your code goes here """
#
# print(f"Gravity acceleration: {acceleration:.2f}")

# %% [markdown]
# ### 2.6.1: Simple program with an arithmetic expression.

# %%
""" Computes the total cost of leasing a car given the down payment,
    monthly rate, and number of months """

down_payment = int(input("Enter down payment: "))
payment_per_month = int(input("Enter monthly payment: "))
num_months = int(input("Enter number of months: "))

total_cost = down_payment + (payment_per_month * num_months)

print (f"Total cost: ${total_cost:.2f}")
# Out:
# Enter down payment: 500
# Enter monthly payment: 300
# Enter number of months: 60
# Total cost: $18500.00

# %%
down_payment + payment_per_month * num_months
# Out:
# 18500

# %%
all_months_cost = payment_per_month * num_months
total_cost = down_payment + all_months_cost
p([all_months_cost,total_cost])
# Out:
# [18000, 18500]

# %% [markdown]
# ### 2.6.2: Single space around operators.

# %%
import random

# Initialize variables with random numbers
houses_block = random.randint(1, 100)
num1 = random.randint(1, 10)
num2 = random.randint(1, 10)
num_balls = random.randint(1, 20)
user_val = random.randint(1, 50)

p(f"Initial houses_block: {houses_block}")
# 1) houses_city = houses_block *10 -> houses_city = houses_block * 10
houses_city = houses_block * 10
p(f"houses_city = {houses_city}")

p(f"Initial num1: {num1}, num2: {num2}")
# 2) total = num1+num2+2 -> total = num1 + num2 + 2
total = num1 + num2 + 2
p(f"total = {total}")

p(f"Initial num_balls: {num_balls}")
# 3) num_balls=num_balls+1 -> num_balls = num_balls + 1
num_balls = num_balls + 1
p(f"num_balls = {num_balls}")

p(f"Initial user_val: {user_val}")
# 4) num_entries = (user_val+1)*2 -> num_entries = (user_val + 1) * 2
num_entries = (user_val + 1) * 2
p(f"num_entries = {num_entries}")
# Out:
# Initial houses_block: 44
# houses_city = 440
# Initial num1: 5, num2: 6
# total = 13
# Initial num_balls: 4
# num_balls = 5
# Initial user_val: 32
# num_entries = 66

# %%
houses_city = houses_block *10
houses_city = houses_block * 10

# %%
total = num1+num2+2
total = num1 + num2 + 2

# %%
num_balls=num_balls+1
num_balls = num_balls + 1

# %%
num_entries = (user_val+1)*2
num_entries = (user_val + 1) * 2

# %% [markdown]
# ### 2.6.3: Compound operators.

# %%
def p(*args, **kwargs):
    print(*args, **kwargs)

# %%
num_atoms += 5
p(f"num_atoms = {num_atoms}")
num_atoms *= 2
p(f"num_atoms = {num_atoms}")
car_count = 10
car_count = car_count / 2
car_count /= 2
p(f"car_count = {car_count}")
box_count = 10
num_items = box_count + 1
p("Not possible")
# Out:
# num_atoms = 83
# num_atoms = 166
# car_count = 2.5
# Not possible

# %% [markdown]
# ###
# 2.6.4: Assigning an integer literal.

# %%
num_years = 2,000,000,000
p(num_years)
# Out:
# (2, 0, 0, 0)

# %%
num_years = 2000000000
p(num_years)
# Out:
# 2000000000

# %% [markdown]
# ### challenge activity 2.6.1: Python expressions.

# %%
distance = float(input())
pp("""##

2.6.1: Python expressions.

712910.5105864.qx3zqy7

Start

The expression for the acceleration of gravity is G⁢R⁢A⁢V⁢I⁢T⁢Y∗M⁢A⁢S⁢Sd⁢i⁢s⁢t⁢a⁢n⁢c⁢e2 where:

-   GRAVITY = the gravitational constant (6.673e-11).
-   MASS = the mass of the Earth in kg (5.98e+24).
-   distance = the distance in meters from the Earth's center, read from input into variable distance.

Compute the approximate acceleration of gravity for an object above the Earth's surface. Assign acceleration with the result.

**Click here for example** Ex: If the input is `6.381293e6`, then the output is:

    Gravity acceleration: 9.80

Note:

-   The input value is a floating-point literal written in scientific notation using an "e" preceding the power-of-10 exponent. The "e" stands for exponent.
-   Ex: 6.02e23 represents 6.02x1023, while 1.0e-3 represents 1x10\-3 or 0.001.

1

2

3

4

5

6

7

8

GRAVITY \= 6.673e-11

MASS \= 5.98e+24

distance \= float(input())

``` Your code goes here ```

print(f"Gravity acceleration: {acceleration:.2f}")
###

""")

GRAVITY = 6.673e-11
MASS = 5.98e+24

#distance = float(input())

""" Your code goes here """
acceleration = GRAVITY * MASS / (distance ** 2)
print(f"Gravity acceleration: {acceleration:.2f}")
# Out:
# <>:25: SyntaxWarning: invalid escape sequence '\-'
# <>:25: SyntaxWarning: invalid escape sequence '\-'
# /tmp/ipython-input-2722132805.py:25: SyntaxWarning: invalid escape sequence '\-'
#   -   Ex: 6.02e23 represents 6.02x1023, while 1.0e-3 represents 1x10\-3 or 0.001.
# 7676
#
#
# 2.6.1: Python expressions.
#
# 712910.5105864.qx3zqy7
#
# Start
#
# The expression for the acceleration of gravity is G⁢R⁢A⁢V⁢I⁢T⁢Y∗M⁢A⁢S⁢Sd⁢i⁢s⁢t⁢a⁢n⁢c⁢e2 where:
#
#  • GRAVITY = the gravitational constant (6.673e-11).
#  • MASS = the mass of the Earth in kg (5.98e+24).
#  • distance = the distance in meters from the Earth's center, read from input into variable distance.
#
# Compute the approximate acceleration of gravity for an object above the Earth's surface. Assign acceleration with
# the result.
#
# Click here for example Ex: If the input is 6.381293e6, then the output is:
#
#
#  Gravity acceleration: 9.80
#
#
# Note:
#
# ...

# %%
pp("Assign eggs_count with the current value of eggs_count minus 10.")
eggs_count = int(input())

print("Initial number of eggs:", eggs_count)

""" Your code goes here """
eggs_count = eggs_count - 10
print("Updated number of eggs:", eggs_count)
# Out:
# Assign eggs_count with the current value of eggs_count minus 10.
# 10
# Initial number of eggs: 10
# Updated number of eggs: 0

# %%
pp('''Assume that yaks weigh 649 pounds each and elk weigh 679 pounds each. Given variables num\_yaks and num\_elk read from input, compute the total weight of all the yaks and elk, and assign total\_weight with the result.

**Click here for example** Ex: If the input is:

    4
    17


then the output is:

    Weight: 14139

''')
yak_pounds = 649
elk_pounds = 679

num_yaks = int(input())
num_elk = int(input())

""" Your code goes here """
total_weight = (num_yaks * yak_pounds) + (num_elk * elk_pounds)


print("Weight:", total_weight)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\_'
# <>:1: SyntaxWarning: invalid escape sequence '\_'
# /tmp/ipython-input-1484957491.py:1: SyntaxWarning: invalid escape sequence '\_'
#   pp('''Assume that yaks weigh 649 pounds each and elk weigh 679 pounds each. Given variables num\_yaks and num\_elk read from input, compute the total weight of all the yaks and elk, and assign total\_weight with the result.
# Assume that yaks weigh 649 pounds each and elk weigh 679 pounds each. Given variables num_yaks and num_elk read
# from input, compute the total weight of all the yaks and elk, and assign total_weight with the result.
#
# Click here for example Ex: If the input is:
#
#
#  4
#  17
#
#
# then the output is:
#
#
#  Weight: 14139
# 4
# 17
# Weight: 14139

# %% [markdown]
# # ====================

# %% [markdown]
# # 2.7 Division and modulo

# %% [markdown]
# ## Division: Integer rounding
#
# The division operator / performs division and returns a floating-point number. Ex:
#
# -   20 / 10 is 2.0.
# -   50 / 50 is 1.0.
# -   5 / 10 is 0.5.
#
# The floor division operator // can be used to round down the result of a floating-point division to the closest smaller whole number value. The resulting value is an integer type if both operands are integers; if either operand is a float, then a float is returned:
#
# -   20 // 10 is 2.
# -   50 // 50 is 1.
# -   5 // 10 is 0. (5 = 10 \* 0 + 5. So, the result is 0 and the remainder 5 is thrown away.)
# -   5.0 // 2 is 2.0.
#
# For division, the second operand of / or // must never be 0, because division by 0 is mathematically undefined.
#
# participation activity
#
# ##
#
# 2.7.1: Division and floor division.
#
# Determine the result. Type "Error" if the program would terminate due to division by 0. If the answer is a floating-point number, answer in the form #.#, even if the answer is a whole number.
#
# 1)
#
# `12 / 4`
#
# Check Show answer
#
# 2)
#
# `5 / 10`
#
# Check Show answer
#
# 3)
#
# `5.0 // 2`
#
# Check Show answer
#
# 4)
#
# `100 / 0`
#
# Check Show answer
#
# Feedback?
#
# ### Modulo (%)
#
# The basic arithmetic operators include not just +, -, \*, /, //, but also %. The modulo operator (%) evaluates the remainder of the division of two integer operands. Ex: 23 % 10 is 3.
#
# Examples:
#
# -   9 % 5 is 4. Reason: Since 9 = 5 \* 1 + 4, the floor division 9 // 5 results in 1, and the remainder is 4.
# -   70 % 7 is 0. Reason: 70 // 7 is 10 with remainder 0.
# -   1 % 2 is 1. Reason: 1 // 2 is 0 with remainder 1.
#
# ##
#
# Try 2.7.1: Example using expressions: Minutes to hours/minutes.
#
# _fullscreen_
#
# Full screen
#
# The program below reads the number of minutes entered by a user. The program then converts the number of minutes to hours and minutes.
#
# Run the program, then modify the code to work in reverse: The user enters two numbers for hours and minutes and the program outputs total minutes.
#
# Feedback?
#
# participation activity
#
# ##
#
# 2.7.2: Modulo.
#
# Determine the result. Type "Error" if appropriate. Only literals appear in these expressions to focus attention on the operators; most practical expressions include variables.
#
# 1)
#
# `50 % 2`
#
# Check Show answer
#
# 2)
#
# `51 % 2`
#
# Check Show answer
#
# 3)
#
# `5 % 3`
#
# Check Show answer
#
# 4)
#
# `27 % 4`
#
# Check Show answer
#
# 5)
#
# `596 % 10`
#
# Check Show answer
#
# 6)
#
# `100 % (1 // 2)`
#
# Check Show answer
#
# Feedback?
#
# challenge activity
#
# ##
#
# 2.7.1: Enter the output of the integer expressions.
#
# 712910.5105864.qx3zqy7
#
#
#
# Start Jump to level 1
#
# Type the program's output
#
# | - main.py x = 18 y = x / 4 print(y) | Input Output |
# | --- | --- |
#
# 1
#
# 2
#
# 3
#
# Check
#
# Next
#
# Try again
#
# question\_mark signifies a specific hint for an answer
#
# Show solution
#
# **Done**. Click any level to practice more. Completion is preserved.
#
# ✖ ![Correct](https://zytools.zybooks.com/zyBooks2/fingerprinted/989bd345-53bb-496c-85f2-cbd4a9e1c55b/utilities/resource/checkmark.png)
#
# Solution
#
# 1
#
# 2
#
# 3
#
# Feedback?
#
# ### Modulo examples
#
# Modulo has several useful applications. Below are just a few.
#
# ##
#
# Example 2.7.1: Getting digits.
#
# Given a number, % and // can be used to get each digit. For a three-digit number user\_val like 927:
#
# ones\_digit     \= user\_val % 10    \# Ex: 927 % 10 is 7.
# tmp\_val        \= user\_val // 10   \#
#
# tens\_digit     \= tmp\_val % 10     \# Ex: tmp\_val = 927 // 10 is 92. Then 92 % 10 is 2.
# tmp\_val        \= tmp\_val // 10
#
# hundreds\_digit \= tmp\_val % 10     \# Ex: tmp\_val = 92 // 10 = 9. Then 9 % 10 is 9.
#
# Feedback?
#
# ##
#
# Example 2.7.2: Get prefix.
#
# Given a 10-digit phone number stored as an integer, % and // can be used to get any part, such as the prefix. For phone\_num = 9365551212 (whose prefix is 555):
#
# tmp\_val = phone\_num // 10000  # "// 10000" removes rightmost 4 digits , so "9365551212 // 10000" is 936555.
# prefix\_num = tmp\_val % 1000 # "% 1000" gets rightmost 3 digits, so "936555 % 1000" is 555.
#
# Dividing by a power of 10 removes rightmost digits. Ex: 321 // 10 is 32. Ex: 321 // 100 is 3.
#
# % by a power of 10 gets rightmost digits. Ex: 321 % 10 is 1. Ex: 321 % 100 is 21.
#
# Feedback?
#
# participation activity
#
# ##
#
# 2.7.3: Modulo examples.
#
# 1)
#
# Given a non-negative number x, which expression has the range of 5 to 10?
#
# x % 5
#
# x % 10
#
# x % 11
#
# (x % 6) + 5
#
# 2)
#
# Given a non-negative number x, which expression has the range -10 to 10?
#
# x % -10
#
# (x % 21) - 10
#
# (x % 20) - 10
#
# 3)
#
# Which expression gets the tens digit of x? Ex: If x = 693, which expression yields 9?
#
# x % 10
#
# x % 100
#
# (x // 10) % 10
#
# 4)
#
# Given a 16-digit credit card number stored in x, which expression gets the rightmost four digits (assume the fourth digit from the right is non-zero)?
#
# x / 10000
#
# x % 10000
#
# Feedback?
#
# challenge activity
#
# ##
#
# 2.7.2: Division and modulo.
#
# 712910.5105864.qx3zqy7
#
# Start
#
# Integers total\_budget and pillow\_cost are read from input. A pillow costs pillow\_cost to make, and a budget is given by total\_budget. Assign remaining\_budget with the remaining budget after making as many pillows as possible.
#
# **Click here for example** Ex: If the input is:
#
#     17
#     2
#
#
# then the output is:
#
#     Remaining budget: 1
#
# 1
#
# 2
#
# 3
#
# 4
#
# 5
#
# 6
#
# total\_budget \= int(input())
#
# pillow\_cost \= int(input())
#
# """ Your code goes here """
#
# print("Remaining budget:", remaining\_budget)
#
#
#
#
#
# 1
#
# 2
#
# 3
#
# Check Next level
#
# 1
#
# 2
#
# 3
#
# Feedback?
#
# How was this section?
#
# _thumb\_up_
#
# |
#
# _thumb\_down_
#
# Provide section feedback

# %% [markdown]
# ###  2.7.1: Division and floor division.

# %%
12 / 4
# Out:
# 3.0

# %%
5 / 10
# Out:
# 0.5

# %%
5.0 // 2
# Out:
# 2.0

# %%
100 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-3039867184.py in <cell line: 0>()
# ----> 1 100 / 0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### Try 2.7.1: Example using expressions: Minutes to hours/minutes.

# %%
minutes = 5
hours = minutes // 60
minutes_remaining = minutes % 60

print(minutes, "minute(s) is", hours, "hour(s) and", minutes_remaining, "minute(s).")
# Out:
# 5 minute(s) is 0 hour(s) and 5 minute(s).

# %% [markdown]
# ### 2.7.2: Modulo.

# %%
 50 % 2
# Out:
# 0

# %%
51 % 2
# Out:
# 1

# %%
5 % 3
# Out:
# 2

# %%
 27 % 4
# Out:
# 3

# %%
596 % 10
# Out:
# 6

# %%
100 % (1 // 2)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-869311579.py in <cell line: 0>()
# ----> 1 100 % (1 // 2)
#
# ZeroDivisionError: integer modulo by zero

# %% [markdown]
# ### 2.7.1: Enter the output of the integer expressions.

# %%
#divide
x = 17
y = x / 2

print(y)
# Out:
# 8.5

# %%
#floor
x = 11
y = x // 5

print(y)
# Out:
# 2

# %%
#remainder
x = 5
y = x % 2

print(y)
# Out:
# 1

# %% [markdown]
# ## 2.7.3: Modulo examples.

# %% [markdown]
# 1)
#
# Given a non-negative number x, which expression has the range of 5 to 10?
#
# x % 5
#
# x % 10
#
# x % 11
#
# (x % 6) + 5
#
# ### Correct
#
# x % 6 yields 0 to 5. Then + 5 yields 5 to 10.
#
# 2)
#
# Given a non-negative number x, which expression has the range -10 to 10?
#
# x % -10
#
# (x % 21) - 10
#
# (x % 20) - 10
#
# ### Correct
#
# x % 21 yields 0 to 20. Then - 10 yields -10 to 10.
#
# 3)
#
# Which expression gets the tens digit of x? Ex: If x = 693, which expression yields 9?
#
# x % 10
#
# x % 100
#
# (x // 10) % 10
#
# ### Correct
#
# x // 10 removes the rightmost digit, putting the tens digit in the ones place. Then % 10 gets the (new) ones digit. Ex: 693 / / 10 is 69, then 69 % 10 is 9.
#
# 4)
#
# Given a 16-digit credit card number stored in x, which expression gets the rightmost four digits (assume the fourth digit from the right is non-zero)?
#
# x / 10000
#
# x % 10000
#
# ### Correct
#
# x % 10000 yields the rightmost four digits. To get other digits like the next four digits, first divide to remove the rightmost digits, then use % to get just those digits.

# %% [markdown]
# # ▶

# %% [markdown]
# ## 2.7.2: Division and modulo.

# %%
pp('''Integers total\_budget and pillow\_cost are read from input. A pillow costs pillow\_cost to make, and a budget is given by total\_budget. Assign remaining\_budget with the remaining budget after making as many pillows as possible.

**Click here for example** Ex: If the input is:

    17
    2


then the output is:

    Remaining budget: 1

''')
total_budget = int(input())
pillow_cost = int(input())

""" Your code goes here """
remaining_budget = total_budget % pillow_cost

print("Remaining budget:", remaining_budget)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\_'
# <>:1: SyntaxWarning: invalid escape sequence '\_'
# /tmp/ipython-input-3463852480.py:1: SyntaxWarning: invalid escape sequence '\_'
#   pp('''Integers total\_budget and pillow\_cost are read from input. A pillow costs pillow\_cost to make, and a budget is given by total\_budget. Assign remaining\_budget with the remaining budget after making as many pillows as possible.
# Integers total_budget and pillow_cost are read from input. A pillow costs pillow_cost to make, and a budget is
# given by total_budget. Assign remaining_budget with the remaining budget after making as many pillows as possible.
#
# Click here for example Ex: If the input is:
#
#
#  17
#  2
#
#
# then the output is:
#
#
#  Remaining budget: 1
# 17
# 2
# Remaining budget: 1

# %%
user_value = int(input())

""" Your code goes here """
remaining_budget = total_budget % pillow_cost
print("Value in thousands place:", thousands_digit)

pp("""Integer user\_value is read from input. Assume user\_value is greater than 10000 and less than 99999. Assign thousands\_digit with user\_value's thousands place value.

**Click here for example** Ex: If the input is `26497`, then the output is:

    Value in thousands place: 6

""")
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\_'
# <>:7: SyntaxWarning: invalid escape sequence '\_'
# /tmp/ipython-input-3147180541.py:7: SyntaxWarning: invalid escape sequence '\_'
#   pp("""Integer user\_value is read from input. Assume user\_value is greater than 10000 and less than 99999. Assign thousands\_digit with user\_value's thousands place value.
# 2657
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3147180541.py in <cell line: 0>()
#       3 """ Your code goes here """
#       4 remaining_budget = total_budget % pillow_cost
# ----> 5 print("Value in thousands place:", thousands_digit)
#       6
#       7 pp("""Integer user\_value is read from input. Assume user\_value is greater than 10000 and less than 99999. Assign thousands\_digit with user\_value's thousands place value.
#
# NameError: name 'thousands_digit' is not defined
